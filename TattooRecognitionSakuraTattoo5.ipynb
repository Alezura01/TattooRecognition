# %% [markdown]
# <a href="https://colab.research.google.com/github/Alezura01/TattooRecognition/blob/main/TattooRecognitionSakuraTattoo5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers==4.32.0 accelerate tiktoken einops
# !pip install -q transformers_stream_generator==0.0.4
# !pip install -q scipy torchvision pillow tensorboard matplotlib
# !pip install -q optimum
# !pip install -q auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 56.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 74.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for transformers_stream_generator (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 53.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 96.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 32.5 MB/s eta 0:00:00

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
torch.manual_seed(1234)

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-VL-Chat-Int4", trust_remote_code=True)

# use cuda device
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-VL-Chat-Int4", device_map="cuda", trust_remote_code=True).eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/21.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen.tiktoken:   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# SimSun.ttf:   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# configuration_qwen.py:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - configuration_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_qwen.py:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# qwen_generation_utils.py:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - qwen_generation_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# visual.py:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - modeling_qwen.py
# - qwen_generation_utils.py
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/126k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.78G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Some weights of the model checkpoint at Qwen/Qwen-VL-Chat-Int4 were not used when initializing QWenLMHeadModel: ['transformer.h.16.mlp.w1.bias', 'transformer.h.19.mlp.w2.bias', 'transformer.h.25.mlp.w2.bias', 'transformer.h.0.mlp.w1.bias', 'transformer.h.4.mlp.w1.bias', 'transformer.h.2.mlp.c_proj.bias', 'transformer.h.17.mlp.w2.bias', 'transformer.h.14.mlp.w1.bias', 'transformer.h.6.mlp.w2.bias', 'transformer.h.1.attn.c_proj.bias', 'transformer.h.14.mlp.c_proj.bias', 'transformer.h.7.mlp.w1.bias', 'transformer.h.20.attn.c_proj.bias', 'transformer.h.14.attn.c_proj.bias', 'transformer.h.28.mlp.w1.bias', 'transformer.h.26.attn.c_proj.bias', 'transformer.h.25.mlp.w1.bias', 'transformer.h.11.attn.c_proj.bias', 'transformer.h.22.attn.c_proj.bias', 'transformer.h.9.mlp.w1.bias', 'transformer.h.17.mlp.c_proj.bias', 'transformer.h.6.mlp.c_proj.bias', 'transformer.h.31.attn.c_proj.bias', 'transformer.h.5.mlp.w2.bias', 'transformer.h.22.mlp.c_proj.bias', 'transformer.h.23.attn.c_proj.bias', 'transformer.h.5.attn.c_proj.bias', 'transformer.h.15.attn.c_proj.bias', 'transformer.h.1.mlp.w1.bias', 'transformer.h.3.attn.c_proj.bias', 'transformer.h.1.mlp.c_proj.bias', 'transformer.h.13.attn.c_proj.bias', 'transformer.h.17.mlp.w1.bias', 'transformer.h.16.mlp.c_proj.bias', 'transformer.h.24.mlp.w2.bias', 'transformer.h.4.mlp.c_proj.bias', 'transformer.h.19.mlp.w1.bias', 'transformer.h.19.mlp.c_proj.bias', 'transformer.h.5.mlp.w1.bias', 'transformer.h.8.attn.c_proj.bias', 'transformer.h.2.attn.c_proj.bias', 'transformer.h.8.mlp.c_proj.bias', 'transformer.h.18.mlp.c_proj.bias', 'transformer.h.14.mlp.w2.bias', 'transformer.h.11.mlp.w1.bias', 'transformer.h.27.mlp.w1.bias', 'transformer.h.27.mlp.c_proj.bias', 'transformer.h.29.mlp.c_proj.bias', 'transformer.h.29.attn.c_proj.bias', 'transformer.h.30.mlp.w2.bias', 'transformer.h.31.mlp.w2.bias', 'transformer.h.25.attn.c_proj.bias', 'transformer.h.16.mlp.w2.bias', 'transformer.h.15.mlp.c_proj.bias', 'transformer.h.0.mlp.c_proj.bias', 'transformer.h.7.attn.c_proj.bias', 'transformer.h.29.mlp.w1.bias', 'transformer.h.12.mlp.w1.bias', 'transformer.h.18.mlp.w1.bias', 'transformer.h.27.mlp.w2.bias', 'transformer.h.3.mlp.w2.bias', 'transformer.h.12.mlp.w2.bias', 'transformer.h.12.mlp.c_proj.bias', 'transformer.h.29.mlp.w2.bias', 'transformer.h.18.mlp.w2.bias', 'transformer.h.9.mlp.w2.bias', 'transformer.h.15.mlp.w1.bias', 'transformer.h.31.mlp.c_proj.bias', 'transformer.h.31.mlp.w1.bias', 'transformer.h.13.mlp.w1.bias', 'transformer.h.30.attn.c_proj.bias', 'transformer.h.3.mlp.w1.bias', 'transformer.h.10.mlp.w1.bias', 'transformer.h.25.mlp.c_proj.bias', 'transformer.h.21.mlp.w2.bias', 'transformer.h.16.attn.c_proj.bias', 'transformer.h.4.mlp.w2.bias', 'transformer.h.20.mlp.c_proj.bias', 'transformer.h.0.attn.c_proj.bias', 'transformer.h.13.mlp.c_proj.bias', 'transformer.h.21.attn.c_proj.bias', 'transformer.h.8.mlp.w2.bias', 'transformer.h.19.attn.c_proj.bias', 'transformer.h.6.mlp.w1.bias', 'transformer.h.30.mlp.w1.bias', 'transformer.h.9.attn.c_proj.bias', 'transformer.h.26.mlp.c_proj.bias', 'transformer.h.21.mlp.w1.bias', 'transformer.h.20.mlp.w2.bias', 'transformer.h.4.attn.c_proj.bias', 'transformer.h.23.mlp.c_proj.bias', 'transformer.h.26.mlp.w1.bias', 'transformer.h.10.mlp.c_proj.bias', 'transformer.h.28.attn.c_proj.bias', 'transformer.h.18.attn.c_proj.bias', 'transformer.h.7.mlp.c_proj.bias', 'transformer.h.12.attn.c_proj.bias', 'transformer.h.5.mlp.c_proj.bias', 'transformer.h.9.mlp.c_proj.bias', 'transformer.h.21.mlp.c_proj.bias', 'transformer.h.8.mlp.w1.bias', 'transformer.h.23.mlp.w2.bias', 'transformer.h.10.mlp.w2.bias', 'transformer.h.27.attn.c_proj.bias', 'transformer.h.28.mlp.w2.bias', 'transformer.h.24.attn.c_proj.bias', 'transformer.h.0.mlp.w2.bias', 'transformer.h.10.attn.c_proj.bias', 'transformer.h.23.mlp.w1.bias', 'transformer.h.6.attn.c_proj.bias', 'transformer.h.11.mlp.w2.bias', 'transformer.h.30.mlp.c_proj.bias', 'transformer.h.22.mlp.w1.bias', 'transformer.h.2.mlp.w2.bias', 'transfo ...
# - This IS expected if you are initializing QWenLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing QWenLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# generation_config.json:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
img='https://drive.google.com/uc?export=view&id=1nGEmkkkbKfpL8RaxrcoogE0yPNVAtain'

# %%
# 1st dialogue turn
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What specific symbols are present in this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo features a samurai helmet adorned with cherry blossoms, which are a significant symbol in Japanese culture. The cherry blossom represents beauty, transience, and the passage of time, while the samurai helmet symbolizes strength, honor, and resilience. Together, these symbols create a visually striking and meaningful tattoo design.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from mafia or gang?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# This tattoo does not necessarily belong to a mafia or gang. The tattoo in the image shows a samurai with a cherry blossom pattern around it, which is a popular tattoo design. Samurais are often depicted as brave and loyal warriors, and cherry blossoms are often associated with beauty, transience, and mortality, which makes this tattoo a unique and meaningful design for many people.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What does this symbol represent in the context of mafia or gang affiliations?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# In the context of mafia or gang affiliations, this tattoo of a samurai helmet surrounded by cherry blossoms may represent a symbolic connection to Japanese culture. The samurai helmet is a traditional Japanese helmet worn by samurais, who were known for their bravery and loyalty. The cherry blossoms are a symbol of beauty, grace, and renewal, which could represent the idea of rebirth or the samurai's ability to rise from the death of their predecessor. However, it is important to note that without additional context, this tattoo could also be seen as simply a design that the individual finds aesthetically appealing.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from a Bloods member?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# There is no evidence to suggest that this tattoo is from a Bloods member. The tattoo is simply aSamurai tattoo with cherry blossoms on the arm, which can be associated with various meanings and have various origins. It is not specific to any particular organization or group.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Where on the body is the tattoo located?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is located on the man's arm.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is there any signifiance to the placement of this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The placement of the tattoo, covering the entire upper arm and shoulder, is significant as it can be a way for the tattooed individual to express their identity, personal story, or connection to a particular culture or historical figure. By covering a significant portion of the upper arm and shoulder, the tattoo becomes a focal point and a way for the individual to share their personal story or connection to a particular theme or idea. Additionally, the tattoo's placement may also serve as a way to cover any previous tattoos or scars on the arm, making it a practical choice as well.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Which is the gang that could use this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Based on the image, the tattoo features a samurai with cherry blossoms, which is a traditional Japanese theme. Therefore, the gang that could use this tattoo is likely a Japanese gang or has connections to Japanese culture. However, it's important to note that using gang tattoos can have negative connotations, so it's essential to consider the cultural and social implications before getting such a tattoo.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does this photo include the word "PIRU"?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# There is no existence of the word "PIRU" in the image.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo colored or not?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# This tattoo is colored.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What is the color of the tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is colorful.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does the tattoo contain any other color except for white and black?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Yes, the tattoo also contains pink color, which is not a part of the traditional white and black tattoo color scheme.
