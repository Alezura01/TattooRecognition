# %% [markdown]
# <a href="https://colab.research.google.com/github/Alezura01/TattooRecognition/blob/main/TattooRecognitionMOBTattoo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers==4.32.0 accelerate tiktoken einops
# !pip install -q transformers_stream_generator==0.0.4
# !pip install -q scipy torchvision pillow tensorboard matplotlib
# !pip install -q optimum
# !pip install -q auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 65.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for transformers_stream_generator (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 54.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 86.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 29.0 MB/s eta 0:00:00

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
torch.manual_seed(1234)

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-VL-Chat-Int4", trust_remote_code=True)

# use cuda device
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-VL-Chat-Int4", device_map="cuda", trust_remote_code=True).eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/21.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen.tiktoken:   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# SimSun.ttf:   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# configuration_qwen.py:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - configuration_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_qwen.py:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# qwen_generation_utils.py:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - qwen_generation_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# visual.py:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - modeling_qwen.py
# - qwen_generation_utils.py
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/126k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.78G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Some weights of the model checkpoint at Qwen/Qwen-VL-Chat-Int4 were not used when initializing QWenLMHeadModel: ['transformer.h.1.attn.c_proj.bias', 'transformer.h.2.mlp.c_proj.bias', 'transformer.h.31.attn.c_proj.bias', 'transformer.h.7.attn.c_proj.bias', 'transformer.h.26.mlp.c_proj.bias', 'transformer.h.7.mlp.c_proj.bias', 'transformer.h.20.mlp.w2.bias', 'transformer.h.13.mlp.c_proj.bias', 'transformer.h.30.mlp.w1.bias', 'transformer.h.29.mlp.w1.bias', 'transformer.h.17.mlp.w1.bias', 'transformer.h.22.mlp.w1.bias', 'transformer.h.13.mlp.w2.bias', 'transformer.h.18.mlp.w2.bias', 'transformer.h.28.mlp.w1.bias', 'transformer.h.31.mlp.c_proj.bias', 'transformer.h.25.attn.c_proj.bias', 'transformer.h.15.mlp.w2.bias', 'transformer.h.14.mlp.c_proj.bias', 'transformer.h.10.mlp.w2.bias', 'transformer.h.5.attn.c_proj.bias', 'transformer.h.23.attn.c_proj.bias', 'transformer.h.7.mlp.w2.bias', 'transformer.h.24.mlp.w2.bias', 'transformer.h.7.mlp.w1.bias', 'transformer.h.20.mlp.w1.bias', 'transformer.h.13.mlp.w1.bias', 'transformer.h.9.mlp.w1.bias', 'transformer.h.3.attn.c_proj.bias', 'transformer.h.19.mlp.c_proj.bias', 'transformer.h.0.mlp.w1.bias', 'transformer.h.24.attn.c_proj.bias', 'transformer.h.21.attn.c_proj.bias', 'transformer.h.14.mlp.w2.bias', 'transformer.h.30.mlp.w2.bias', 'transformer.h.29.mlp.w2.bias', 'transformer.h.27.mlp.w2.bias', 'transformer.h.13.attn.c_proj.bias', 'transformer.h.16.mlp.c_proj.bias', 'transformer.h.15.mlp.w1.bias', 'transformer.h.12.attn.c_proj.bias', 'transformer.h.28.attn.c_proj.bias', 'transformer.h.30.mlp.c_proj.bias', 'transformer.h.17.mlp.c_proj.bias', 'transformer.h.11.mlp.w2.bias', 'transformer.h.26.attn.c_proj.bias', 'transformer.h.12.mlp.w2.bias', 'transformer.h.18.mlp.c_proj.bias', 'transformer.h.27.mlp.c_proj.bias', 'transformer.h.8.mlp.w1.bias', 'transformer.h.16.attn.c_proj.bias', 'transformer.h.26.mlp.w1.bias', 'transformer.h.25.mlp.w2.bias', 'transformer.h.15.attn.c_proj.bias', 'transformer.h.29.attn.c_proj.bias', 'transformer.h.11.attn.c_proj.bias', 'transformer.h.12.mlp.c_proj.bias', 'transformer.h.23.mlp.c_proj.bias', 'transformer.h.29.mlp.c_proj.bias', 'transformer.h.5.mlp.c_proj.bias', 'transformer.h.19.mlp.w1.bias', 'transformer.h.12.mlp.w1.bias', 'transformer.h.23.mlp.w2.bias', 'transformer.h.4.mlp.w1.bias', 'transformer.h.31.mlp.w2.bias', 'transformer.h.10.attn.c_proj.bias', 'transformer.h.0.mlp.w2.bias', 'transformer.h.22.mlp.c_proj.bias', 'transformer.h.25.mlp.c_proj.bias', 'transformer.h.16.mlp.w2.bias', 'transformer.h.21.mlp.w2.bias', 'transformer.h.11.mlp.c_proj.bias', 'transformer.h.8.mlp.c_proj.bias', 'transformer.h.20.attn.c_proj.bias', 'transformer.h.11.mlp.w1.bias', 'transformer.h.21.mlp.c_proj.bias', 'transformer.h.8.mlp.w2.bias', 'transformer.h.27.mlp.w1.bias', 'transformer.h.6.attn.c_proj.bias', 'transformer.h.28.mlp.c_proj.bias', 'transformer.h.20.mlp.c_proj.bias', 'transformer.h.10.mlp.w1.bias', 'transformer.h.3.mlp.w2.bias', 'transformer.h.30.attn.c_proj.bias', 'transformer.h.18.attn.c_proj.bias', 'transformer.h.5.mlp.w1.bias', 'transformer.h.19.mlp.w2.bias', 'transformer.h.15.mlp.c_proj.bias', 'transformer.h.6.mlp.c_proj.bias', 'transformer.h.9.mlp.w2.bias', 'transformer.h.26.mlp.w2.bias', 'transformer.h.14.attn.c_proj.bias', 'transformer.h.3.mlp.w1.bias', 'transformer.h.6.mlp.w2.bias', 'transformer.h.9.attn.c_proj.bias', 'transformer.h.1.mlp.c_proj.bias', 'transformer.h.17.mlp.w2.bias', 'transformer.h.2.mlp.w2.bias', 'transformer.h.16.mlp.w1.bias', 'transformer.h.0.attn.c_proj.bias', 'transformer.h.6.mlp.w1.bias', 'transformer.h.4.attn.c_proj.bias', 'transformer.h.1.mlp.w2.bias', 'transformer.h.31.mlp.w1.bias', 'transformer.h.27.attn.c_proj.bias', 'transformer.h.2.mlp.w1.bias', 'transformer.h.19.attn.c_proj.bias', 'transformer.h.24.mlp.c_proj.bias', 'transformer.h.14.mlp.w1.bias', 'transformer.h.22.mlp.w2.bias', 'transformer.h.1.mlp.w1.bias', 'transformer.h.4.mlp.c_proj.bias', 'transformer.h.22.attn.c_proj.bias', 'transformer.h.21.mlp.w1.bias', 'transformer.h. ...
# - This IS expected if you are initializing QWenLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing QWenLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# generation_config.json:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
img='https://drive.google.com/uc?export=view&id=1nQKdmmBns8hAnZaf8RqjiIDOWnlRKotq'

# %%
# 1st dialogue turn
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What specific symbols are present in this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo features the letters "K, D, 2020" in a circular formation.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from mafia or gang? Answer gang or mafia.'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# This tattoo is from the "1% Crew" which is a motorcycle gang.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What does this symbol represent in the context of mafia or gang affiliations?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The symbol of a hand with the word "Gang" on it, as seen in the image, is commonly associated with mafia or gang affiliations. This symbol, known as the "Gang Hand," is used by various criminal organizations to represent their membership and demonstrate their loyalty to the group. The hand gesture, often combined with other symbols or markings, serves as a way for members to identify each other and communicate their affiliation without being easily detected by law enforcement.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from a Bloods gang member?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# There is no existence of a Bloods gang member or any gang affiliation in the image description.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Where on the body is the tattoo located?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is located on the player's right foot.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is there any signifiance to the placement of this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# There is no significance to the placement of this tattoo as it is just a random image without any context.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Which is the gang that could use this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Based on the image, the tattoo is a white ink tattoo on the inner side of the ankle, with the text "WAGS". It's difficult to determine the specific gang that could use this tattoo without further context or information about the individual who got the tattoo. Gang tattoos can be symbolic and have different meanings depending on the gang, their history, and the individual's association with the gang.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does this photo include the word "PIRU"?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Yes, the photo includes the word "PIRU" written on the shoe.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo colored or not?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The image shows that the tattoo is in black and white.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What is the color of the tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is in black and white.
