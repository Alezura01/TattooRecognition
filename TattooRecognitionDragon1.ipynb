# %% [markdown]
# <a href="https://colab.research.google.com/github/Alezura01/TattooRecognition/blob/main/TattooRecognitionDragon1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers==4.32.0 accelerate tiktoken einops
# !pip install -q transformers_stream_generator==0.0.4
# !pip install -q scipy torchvision pillow tensorboard matplotlib
# !pip install -q optimum
# !pip install -q auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 55.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 32.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.3 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
torch.manual_seed(1234)

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-VL-Chat-Int4", trust_remote_code=True)

# use cuda device
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-VL-Chat-Int4", device_map="cuda", trust_remote_code=True).eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/21.9k [00:00<?, ?B/s]
# ...

# %%
img='https://drive.google.com/uc?export=view&id=1X_JmzlMn7MC9R5p2UE3FlsCwdCo_kNOu'

# %%
# 1st dialogue turn
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What specific symbols are present in this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo features a dragon, clouds, and flowers as its primary symbols. The dragon is depicted in a colorful and intricate manner, possibly representing strength, power, or a connection to one's heritage. The clouds add a sense of depth and dimension to the design, while the flowers contribute to the overall aesthetic appeal of the tattoo.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from mafia or gang? Answer gang or mafia.'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# This tattoo is from the "Mishima" gang, also known as the "Red Scorpion" gang, which is based in Chicago.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What does this symbol represent in the context of mafia or gang affiliations?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# In the context of mafia or gang affiliations, the symbol of a dragon often represents a certain gang or criminal organization. The dragon is a powerful and majestic creature that is associated with strength, courage, and wisdom. In this context, the dragon symbol may represent the strength and majesty of the gang or organization, as well as the values and principles that its members hold dear. It is important to note that the use of symbols in gang affiliations can be a way to show solidarity and affiliation, but it can also be used to intimidate or threaten others.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from a Triad member?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# There is no existence of any Triad member or any association with a Triad in the image description.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Where on the body is the tattoo located?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is located on the arm.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is there any signifiance to the placement of this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The placement of the tattoo on the upper arm might be significant. Upper arms are typically more exposed and visible, which could mean that the individual wants to showcase their tattoo or make a statement with it. Additionally, the arm is a central part of the body, and having a tattoo on it can be a way for the individual to express their personal style, identity, or connect with their cultural heritage, especially if the tattoo is inspired by Asian or Japanese designs.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Which is the gang that could use this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Based on the image, it is difficult to determine the specific gang that this tattoo might be associated with. Gang tattoos often have a complex history and meaning, often representing the individual's gang affiliation, criminal activities, or personal identity. Without more information about the specific tattoo design and its context, it is not possible to accurately determine the gang it could be associated with.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does this photo include a tiger?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# No, there is no tiger in this photo. The image shows a cover-up tattoo of a dragon on someone's arm.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo colored or not?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is colored, featuring a green and blue dragon.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What is the color of the tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is in green and blue color.
