# %% [markdown]
# <a href="https://colab.research.google.com/github/Alezura01/TattooRecognition/blob/main/TattooRecognitionOniTattoo5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers==4.32.0 accelerate tiktoken einops
# !pip install -q transformers_stream_generator==0.0.4
# !pip install -q scipy torchvision pillow tensorboard matplotlib
# !pip install -q optimum
# !pip install -q auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 54.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 51.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for transformers_stream_generator (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 37.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 54.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 91.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 32.0 MB/s eta 0:00:00

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
torch.manual_seed(1234)

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-VL-Chat-Int4", trust_remote_code=True)

# use cuda device
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-VL-Chat-Int4", device_map="cuda", trust_remote_code=True).eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/21.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen.tiktoken:   0%|          | 0.00/2.56M [00:00<?, ?B/s]
# SimSun.ttf:   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# configuration_qwen.py:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - configuration_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_qwen.py:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# visual.py:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - visual.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# qwen_generation_utils.py:   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - qwen_generation_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/Qwen/Qwen-VL-Chat-Int4:
# - modeling_qwen.py
# - visual.py
# - qwen_generation_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/126k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.78G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Some weights of the model checkpoint at Qwen/Qwen-VL-Chat-Int4 were not used when initializing QWenLMHeadModel: ['transformer.h.10.mlp.w2.bias', 'transformer.h.30.mlp.w1.bias', 'transformer.h.0.mlp.w1.bias', 'transformer.h.19.attn.c_proj.bias', 'transformer.h.28.attn.c_proj.bias', 'transformer.h.25.mlp.w2.bias', 'transformer.h.14.attn.c_proj.bias', 'transformer.h.7.attn.c_proj.bias', 'transformer.h.21.mlp.c_proj.bias', 'transformer.h.26.mlp.c_proj.bias', 'transformer.h.21.mlp.w2.bias', 'transformer.h.10.mlp.w1.bias', 'transformer.h.27.attn.c_proj.bias', 'transformer.h.18.attn.c_proj.bias', 'transformer.h.19.mlp.w2.bias', 'transformer.h.4.mlp.w2.bias', 'transformer.h.1.mlp.w2.bias', 'transformer.h.22.mlp.w1.bias', 'transformer.h.26.mlp.w1.bias', 'transformer.h.23.mlp.c_proj.bias', 'transformer.h.15.attn.c_proj.bias', 'transformer.h.5.attn.c_proj.bias', 'transformer.h.5.mlp.w1.bias', 'transformer.h.11.mlp.w2.bias', 'transformer.h.16.mlp.w2.bias', 'transformer.h.24.mlp.w1.bias', 'transformer.h.4.mlp.c_proj.bias', 'transformer.h.23.attn.c_proj.bias', 'transformer.h.24.mlp.w2.bias', 'transformer.h.30.mlp.w2.bias', 'transformer.h.8.mlp.w2.bias', 'transformer.h.31.mlp.w2.bias', 'transformer.h.8.mlp.c_proj.bias', 'transformer.h.3.mlp.w1.bias', 'transformer.h.0.mlp.w2.bias', 'transformer.h.5.mlp.w2.bias', 'transformer.h.31.attn.c_proj.bias', 'transformer.h.29.attn.c_proj.bias', 'transformer.h.31.mlp.w1.bias', 'transformer.h.6.mlp.w1.bias', 'transformer.h.12.attn.c_proj.bias', 'transformer.h.29.mlp.c_proj.bias', 'transformer.h.9.mlp.c_proj.bias', 'transformer.h.17.mlp.w1.bias', 'transformer.h.19.mlp.w1.bias', 'transformer.h.11.attn.c_proj.bias', 'transformer.h.16.mlp.w1.bias', 'transformer.h.13.mlp.c_proj.bias', 'transformer.h.28.mlp.w2.bias', 'transformer.h.17.attn.c_proj.bias', 'transformer.h.4.mlp.w1.bias', 'transformer.h.19.mlp.c_proj.bias', 'transformer.h.20.mlp.w2.bias', 'transformer.h.22.mlp.c_proj.bias', 'transformer.h.18.mlp.w1.bias', 'transformer.h.16.attn.c_proj.bias', 'transformer.h.26.attn.c_proj.bias', 'transformer.h.28.mlp.w1.bias', 'transformer.h.9.mlp.w1.bias', 'transformer.h.17.mlp.c_proj.bias', 'transformer.h.3.mlp.w2.bias', 'transformer.h.14.mlp.c_proj.bias', 'transformer.h.14.mlp.w1.bias', 'transformer.h.26.mlp.w2.bias', 'transformer.h.21.attn.c_proj.bias', 'transformer.h.15.mlp.w1.bias', 'transformer.h.25.attn.c_proj.bias', 'transformer.h.11.mlp.c_proj.bias', 'transformer.h.0.attn.c_proj.bias', 'transformer.h.2.attn.c_proj.bias', 'transformer.h.13.attn.c_proj.bias', 'transformer.h.2.mlp.c_proj.bias', 'transformer.h.20.mlp.w1.bias', 'transformer.h.30.attn.c_proj.bias', 'transformer.h.30.mlp.c_proj.bias', 'transformer.h.17.mlp.w2.bias', 'transformer.h.27.mlp.w1.bias', 'transformer.h.22.attn.c_proj.bias', 'transformer.h.24.attn.c_proj.bias', 'transformer.h.21.mlp.w1.bias', 'transformer.h.25.mlp.w1.bias', 'transformer.h.0.mlp.c_proj.bias', 'transformer.h.6.mlp.c_proj.bias', 'transformer.h.22.mlp.w2.bias', 'transformer.h.8.attn.c_proj.bias', 'transformer.h.1.attn.c_proj.bias', 'transformer.h.31.mlp.c_proj.bias', 'transformer.h.3.attn.c_proj.bias', 'transformer.h.12.mlp.w2.bias', 'transformer.h.25.mlp.c_proj.bias', 'transformer.h.9.mlp.w2.bias', 'transformer.h.11.mlp.w1.bias', 'transformer.h.16.mlp.c_proj.bias', 'transformer.h.20.attn.c_proj.bias', 'transformer.h.24.mlp.c_proj.bias', 'transformer.h.7.mlp.c_proj.bias', 'transformer.h.1.mlp.c_proj.bias', 'transformer.h.20.mlp.c_proj.bias', 'transformer.h.4.attn.c_proj.bias', 'transformer.h.18.mlp.c_proj.bias', 'transformer.h.3.mlp.c_proj.bias', 'transformer.h.23.mlp.w2.bias', 'transformer.h.27.mlp.c_proj.bias', 'transformer.h.6.mlp.w2.bias', 'transformer.h.23.mlp.w1.bias', 'transformer.h.7.mlp.w2.bias', 'transformer.h.6.attn.c_proj.bias', 'transformer.h.29.mlp.w1.bias', 'transformer.h.18.mlp.w2.bias', 'transformer.h.7.mlp.w1.bias', 'transformer.h.13.mlp.w2.bias', 'transformer.h.10.attn.c_proj.bias', 'transformer.h.29.mlp.w2.bias', 'transformer.h.12.mlp.w1.bias', 'transform ...
# - This IS expected if you are initializing QWenLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing QWenLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# generation_config.json:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
img='https://drive.google.com/uc?export=view&id=1EykU01XRoKHyA0T9VqPIwx0zkpB0d5s9'

# %%
# 1st dialogue turn
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What specific symbols are present in this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo features a red face mask, which is a symbol of a traditional Japanese mask called "Hannya mask". This mask is often used in Noh, a traditional form of Japanese theater. The mask typically has a fierce or devilish appearance, which could represent the temporary nature of happiness and the struggle between good and evil. The red color of the mask further emphasizes its connection to Japanese culture and tradition.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from mafia or gang? Answer gang or mafia.'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# This tattoo does not indicate any affiliation with mafia or gang. It is a decorative tattoo that is popular among many people.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What does this symbol represent in the context of mafia or gang affiliations?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The red hannya mask tattoo, which is a traditional Japanese design, does not typically have a direct connection to mafia or gang affiliations. The hannya mask is a symbol of a Japanese kabuki theater character, specifically the Oni or demon, who is known for their powerful and intense performances. In tattoos, the hannya mask often represents transformation, both physically and emotionally, and can symbolize inner strength and resilience. In the context of mafia or gang affiliations, it is more likely that the tattoo would represent a personal or cultural connection to Japanese culture, rather than any specific affiliation with a gang or mafia organization.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from a Yakuza member?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The origin of the tattoo cannot be determined solely from the image. It is possible that the tattoo is from a Yakuza member, but it is also possible that it is from someone else. Yakuza members often wear tattoos as a form of identification and to demonstrate their social status, but not all tattoos worn by Japanese people are from Yakuza members.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Where on the body is the tattoo located?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is located on the man's upper arm.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is there any signifiance to the placement of this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The placement of the tattoo, which is on the arm, is significant as it is often associated with traditional Japanese tattoos. These tattoos often feature Japanese culture, mythology, and symbolism. The red mask in the image could be a representation of the Japanese oni mask, which is associated with demons and spirits. The placement on the arm makes it easily visible and can be a form of expression or a representation of personal identity.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Which is the gang that could use this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Based on the image, it is difficult to determine the specific gang that could use this tattoo. The image shows a red mask tattoo on an arm, but without additional context or information about the design, it is not possible to determine its significance or association with any particular gang. Gang tattoos can be highly individualized and may have various meanings depending on the person's background, affiliations, and experiences.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does this photo include a tiger?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# No, there is no tiger in this photo. The image shows a tattoo on someone's arm.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo colored or not?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Yes, the tattoo is colored.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What is the color of the tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is red and colorful.
